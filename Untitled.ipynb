# %%
# Import necessary libraries
import pandas as pd
import matplotlib.pyplot as plt
import numpy as np
from IPython.display import HTML

# Define the sections of the measurement management system
planificación = ['Política de calidad', 'Objetivos de calidad', 'Revisión de la dirección']
rendimiento = ['Proceso de medición', 'Equipo de medición', 'Trazabilidad de la medición']
análisis = ['Análisis de datos', 'Gestión de no conformidades', 'Acción correctiva y preventiva']

# Define the index using HTML and CSS
index = '''
<style>
  .index {
    display: flex;
    flex-wrap: wrap;
    justify-content: space-between;
    padding: 10px;
    background-color: #f2f2f2;
  }
  
  .index h3 {
    margin-top: 0;
    font-size: 24px;
  }
  
  .index ul {
    list-style: none;
    margin: 0;
    padding: 0;
  }
  
  .index ul li {
    margin: 0 0 10px 0;
    font-size: 18px;
    cursor: pointer;
  }
  
  .index ul li:hover {
    color: #ff0000;
  }
</style>

<div class="index">
  <div>
   <h3>Planificación</h3>
     <ul>
       <li>Política de calidad</li>
       <li>Objetivos de calidad</li>
       <li>Revisión de la dirección</li>
     </ul>
   </div>
   <div>
     <h3>Rendimiento</h3>
     <ul>
       <li>Proceso de medición</li>
       <li>Equipos de medición</li>
       <li>Trazabilidad de la medición</li>
     </ul>
   </div>
   <div>
     <h3>Análisis</h3>
     <ul>
       <li>Análisis de datos</li>
       <li>Gestión de no conformidades</li>
       <li>Acción correctiva y preventiva</li>
     </ul>
   </div>
</div>
'''

# Use the HTML function to render the index
from IPython.display import HTML

# Define the HTML code for the menu
menu_html = '''
<style>
  /* CSS styles for the menu */
</style>

<!-- HTML code for the menu -->
'''

# Use the HTML function to render the menu
HTML(menu_html)

# Commit and push changes to the repository
# !git add .
# !git commit -m "Added index for measurement management system"
# !git push origin main
# Out:
# On branch main
# Your branch is ahead of 'origin/main' by 2 commits.
#   (use "git push" to publish your local commits)
#
# nothing to commit, working tree clean
# To https://github.com/MASR27/SGMELB
#  ! [rejected]        main -> main (fetch first)
# error: failed to push some refs to 'https://github.com/MASR27/SGMELB'
# hint: Updates were rejected because the remote contains work that you do
# hint: not have locally. This is usually caused by another repository pushing
# hint: to the same ref. You may want to first integrate the remote changes
# hint: (e.g., 'git pull ...') before pushing again.
# hint: See the 'Note about fast-forwards' in 'git push --help' for details.

# %%
# Import necessary libraries
import pandas as pd
import matplotlib.pyplot as plt
import numpy as np
from IPython.display import display, HTML, Markdown

# Define the sections of the measurement management system
Planeación = ['Politica de calidad', 'Objetivos', 'Revisión del Alta Dirección']
Desempeño = ['Proceso de medición', 'Equipo de medición', 'Trazabilidad']
Análisis = ['Análisis de datos', 'Getión de no conformidades', 'Acciónes correctivas y preventivas']

# Define the HTML code for the menu
menu_html = '''
<style>
  .menu {
    display: flex;
    justify-content: space-between;
    align-items: center;
    padding: 10px;
    background-color: #f2f2f2;
  }
  
  .menu ul {
    list-style: none;
    margin: 0;
    padding: 0;
    display: flex;
  }
  
  .menu ul li {
    margin: 0 10px;
    font-size: 18px;
    font-weight: bold;
    cursor: pointer;
  }
  
  .menu ul li:hover {
    color: #ff0000;
  }
</style>

<div class="menu">
  <h2>ISO 10012:2003 Sistema de Gestion de Medición</h2>
  <ul>
    <li>Planificación</li>
    <li>Desempeño</li>
    <li>Analisis</li>
  </ul>
</div>
'''

# Use the display function to render the menu
display(HTML(menu_html))

# Define the Markdown syntax for the planning section
Planeación_md = '''
# Planificación

## Política de Calidad

## Objetivos

## Revisión de la Gestión
'''

# Define the Markdown syntax for the performance section
Desempeño_md = '''
# Desempeño

## Proceso de Medición

## Equipos e Instrumentos de Medición

## Trazabilidad de las Mediciones
'''

# Define the Markdown syntax for the analysis section
Análisis_md = '''
# Análisis

## Análisis de Datos

## Gestión de no conformidades

## Plan de acciones preventivas y correctivas
'''

# Use the display function to render the planning section
display(Markdown(Planeación_md))

# Use the display function to render the performance section
display(Markdown(Desempeño_md))

# Use the display function to render the analysis section
display(Markdown(Análisis_md))

# Commit and push changes to the repository
# !git add .
# !git commit -m "Added web menu and web page for ISO 10012:2003 measurement management system for a gas station"
# !git push origin main
# Out:
# <style>
#   .menu {
#     display: flex;
#     justify-content: space-between;
#     align-items: center;
#     padding: 10px;
#     background-color: #f2f2f2;
#   }
#
#   .menu ul {
#     list-style: none;
#     margin: 0;
#     padding: 0;
#     display: flex;
#   }
#
#   .menu ul li {
#     margin: 0 10px;
#     font-size: 18px;
#     font-weight: bold;
#     cursor: pointer;
#   }
#
#   .menu ul li:hover {
#     color: #ff0000;
#   }
# </style>
#
# <div class="menu">
#   <h2>ISO 10012:2003 Sistema de Gestion de Medición</h2>
#   <ul>
#     <li>Planificación</li>
#     <li>Desempeño</li>
#     <li>Analisis</li>
#   </ul>
# </div>
# # Planificación
#
# ## Política de Calidad
#
# ## Objetivos
#
# ## Revisión de la Gestión
# # Desempeño
#
# ## Proceso de Medición
#
# ## Equipos e Instrumentos de Medición
#
# ## Trazabilidad de las Mediciones
# # Análisis
#
# ## Análisis de Datos
#
# ## Gestión de no conformidades
#
# ## Plan de acciones preventivas y correctivas
# On branch main
# ...

# %%
# !pip install IPython

# %%
# Import necessary libraries
import pandas as pd
import matplotlib.pyplot as plt
import numpy as np
from IPython.display import HTML

# Define the HTML code for the menu
menu_html = '''
<style>
  .menu {
    display: flex;
    justify-content: space-between;
    align-items: center;
    padding: 10px;
    background-color: #f2f2f2;
  }
  
  .menu ul {
    list-style: none;
    margin: 0;
    padding: 0;
    display: flex;
  }
  
  .menu ul li {
    margin: 0 10px;
    font-size: 18px;
    font-weight: bold;
    cursor: pointer;
  }
  
  .menu ul li:hover {
    color: #ff0000;
  }
</style>

<div class="menu">
  <h2>ISO 10012:2003 Measurement Management System</h2>
  <ul>
    <li>Planning</li>
    <li>Performance</li>
    <li>Analysis</li>
  </ul>
</div>
'''

# Use the HTML function to render the menu
HTML(menu_html)

# Commit and push changes to the repository
# !git add .
# !git commit -m "Added web menu for ISO 10012:2003 measurement management system"
# !git push origin main
# Out:
# On branch main
# Your branch is ahead of 'origin/main' by 2 commits.
#   (use "git push" to publish your local commits)
#
# nothing to commit, working tree clean
# To https://github.com/MASR27/SGMELB
#  ! [rejected]        main -> main (fetch first)
# error: failed to push some refs to 'https://github.com/MASR27/SGMELB'
# hint: Updates were rejected because the remote contains work that you do
# hint: not have locally. This is usually caused by another repository pushing
# hint: to the same ref. You may want to first integrate the remote changes
# hint: (e.g., 'git pull ...') before pushing again.
# hint: See the 'Note about fast-forwards' in 'git push --help' for details.

# %%
# Import necessary libraries
import pandas as pd
import matplotlib.pyplot as plt
import numpy as np
from IPython.display import display, HTML, Markdown

# Define the sections of the measurement management system
Planeación = ['Politica de calidad', 'Objetivos', 'Revisión del Alta Dirección']
Desempeño = ['Proceso de medición', 'Equipo de medición', 'Trazabilidad']
Análisis = ['Análisis de datos', 'Getión de no conformidades', 'Acciónes correctivas y preventivas']

# Define the HTML code for the menu
menu_html = '''
<style>
  .menu {
    display: flex;
    justify-content: space-between;
    align-items: center;
    padding: 10px;
    background-color: #f2f2f2;
  }
  
  .menu ul {
    list-style: none;
    margin: 0;
    padding: 0;
    display: flex;
  }
  
  .menu ul li {
    margin: 0 10px;
    font-size: 18px;
    font-weight: bold;
    cursor: pointer;
  }
  
  .menu ul li:hover {
    color: #ff0000;
  }
</style>

<div class="menu">
  <h2>ISO 10012:2003 Sistema de Gestion de Medición</h2>
  <ul>
    <li>Planificación</li>
    <li>Desempeño</li>
    <li>Analisis</li>
  </ul>
</div>
'''

# Use the display function to render the menu
display(HTML(menu_html))

# Define the Markdown syntax for the planning section
Planeación_md = '''
# Planificación

## Política de Calidad

## Objetivos

## Revisión de la Gestión
'''

# Define the Markdown syntax for the performance section
Desempeño_md = '''
# Desempeño

## Proceso de Medición

## Equipos e Instrumentos de Medición

## Trazabilidad de las Mediciones
'''

# Define the Markdown syntax for the analysis section
Análisis_md = '''
# Análisis

## Análisis de Datos

## Gestión de no conformidades

## Plan de acciones preventivas y correctivas
'''

# Use the display function to render the planning section
display(Markdown(Planeación_md))

# Use the display function to render the performance section
display(Markdown(Desempeño_md))

# Use the display function to render the analysis section
display(Markdown(Análisis_md))

# Commit and push changes to the repository
# !git add .
# !git commit -m "Added web menu and web page for ISO 10012:2003 measurement management system for a gas station"
# !git push origin main
# Out:
# <style>
#   .menu {
#     display: flex;
#     justify-content: space-between;
#     align-items: center;
#     padding: 10px;
#     background-color: #f2f2f2;
#   }
#
#   .menu ul {
#     list-style: none;
#     margin: 0;
#     padding: 0;
#     display: flex;
#   }
#
#   .menu ul li {
#     margin: 0 10px;
#     font-size: 18px;
#     font-weight: bold;
#     cursor: pointer;
#   }
#
#   .menu ul li:hover {
#     color: #ff0000;
#   }
# </style>
#
# <div class="menu">
#   <h2>ISO 10012:2003 Sistema de Gestion de Medición</h2>
#   <ul>
#     <li>Planificación</li>
#     <li>Desempeño</li>
#     <li>Analisis</li>
#   </ul>
# </div>
# # Planificación
#
# ## Política de Calidad
#
# ## Objetivos
#
# ## Revisión de la Gestión
# # Desempeño
#
# ## Proceso de Medición
#
# ## Equipos e Instrumentos de Medición
#
# ## Trazabilidad de las Mediciones
# # Análisis
#
# ## Análisis de Datos
#
# ## Gestión de no conformidades
#
# ## Plan de acciones preventivas y correctivas
# On branch main
# ...

# %%
# Import necessary libraries
import pandas as pd
import matplotlib.pyplot as plt
import numpy as np
from IPython.display import display, HTML

# Define the HTML code for the menu
menu_html = '''
<style>
  .menu {
    display: flex;
    justify-content: space-between;
    align-items: center;
    padding: 10px;
    background-color: #f2f2f2;
  }
  
  .menu ul {
    list-style: none;
    margin: 0;
    padding: 0;
    display: flex;
  }
  
  .menu ul li {
    margin: 0 10px;
    font-size: 18px;
    font-weight: bold;
    cursor: pointer;
  }
  
  .menu ul li:hover {
    color: #ff0000;
  }
</style>

<div class="menu">
  <h2>ISO 10012:2003 Sistema de Gestion de Medición</h2>
  <ul>
    <li>Planificación</li>
    <li>Desempeño</li>
    <li>Analisis</li>
  </ul>
</div>
'''

# Use the display function to render the menu
display(HTML(menu_html))

# Commit and push changes to the repository
# !git add .
# !git commit -m "Added web menu for ISO 10012:2003 measurement management system"
# !git push origin main
# Out:
# <style>
#   .menu {
#     display: flex;
#     justify-content: space-between;
#     align-items: center;
#     padding: 10px;
#     background-color: #f2f2f2;
#   }
#
#   .menu ul {
#     list-style: none;
#     margin: 0;
#     padding: 0;
#     display: flex;
#   }
#
#   .menu ul li {
#     margin: 0 10px;
#     font-size: 18px;
#     font-weight: bold;
#     cursor: pointer;
#   }
#
#   .menu ul li:hover {
#     color: #ff0000;
#   }
# </style>
#
# <div class="menu">
#   <h2>ISO 10012:2003 Sistema de Gestion de Medición</h2>
#   <ul>
#     <li>Planificación</li>
#     <li>Desempeño</li>
#     <li>Analisis</li>
#   </ul>
# </div>
# On branch main
# Your branch is ahead of 'origin/main' by 2 commits.
#   (use "git push" to publish your local commits)
#
# nothing to commit, working tree clean
# To https://github.com/MASR27/SGMELB
#  ! [rejected]        main -> main (fetch first)
# error: failed to push some refs to 'https://github.com/MASR27/SGMELB'
# ...
